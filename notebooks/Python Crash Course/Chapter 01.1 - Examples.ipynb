# %% [markdown]
# # String methods

# %%
# title() method example

name = 'jake smith'
name.title()
# Out:
# 'Jake Smith'

# %%
#  String method example

name.upper()
# Out:
# 'JAKE SMITH'

# %%
#  String method example

name.lower()
# Out:
# 'jake smith'

# %%
# f-string example

first_name = 'Sarah'
last_name = 'Leslie'
full_name = f'{first_name} {last_name}'
full_name
# Out:
# 'Sarah Leslie'

# %%
# strip() example

my_text = '   hello   world !    '
my_text = my_text.strip()
my_text
# Out:
# 'hello   world !'
