# %% [markdown]
# <h1 style="text-align: center; color: rgb(6,64,43)">↓ Python - Roadmap ↓</h1>
#
# <img src="static/Python_Roadmap.jpeg" alt="roadmap_image_not_found" style="display:flex; width: 80%; margin:auto;">
