# %% [markdown]
# # Business Analytics, Data Analytics, and Data Science
#
# <img src="static/BusA,DataA,DataS.png">
#
# 🔽 🔽 🔽 🔽 🔽 🔽

# %% [markdown]
# ## Timeline
#
# <hr>
#
# ### PAST
#
# Business case studies - <span style="color: rgb(100,190,230);">Business Analytics</span>
#
# Preliminary Data Report (EDA / Exploratory data analysis) <span style="color: rgb(100,230,180);">Data Science</span>
#
# Reporting with visuals <span style="color: rgb(230,160,50);">Business Inteligence</span>
#
# Creating Dashboards <span style="color: rgb(230,160,50);">Business Inteligence</span>
#
# Creating real-time dashboards <span style="color: rgb(230,160,50);">Business Inteligence</span>
#
# <hr>
#
# ### FUTURE
#
# Qualitative Analytics - <span style="color: rgb(100,190,230);">Business Analytics</span>
#
# Sales Forecasting <span style="color: rgb(100,230,180);">Data Science</span>
#
# Optimization of drilling operations <span style="color: rgb(100,230,180);">Data Science</span>
#
# Client retention <span style="color: rgb(100,230,180);">Data Science</span>
#
# Fraud prevention <span style="color: rgb(100,230,180);">Data Science</span>
#
# Digital signal processing <span style="color: rgb(250,150,180);">Data Analytics</span>
